# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import ImageFile
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Ensure that truncated images are loaded
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Parameters
img_height = 224  # VGG16 requires 224x224 images
img_width = 224
batch_size = 32
directory = r"/Users/shauryasharma/Downloads/Indian Medicinal Leaves Image Datasets/Medicinal Leaf dataset"

# Define data generator without augmentation
datagen = ImageDataGenerator(
    validation_split=0.2  # Add validation split here
)

# Load the training dataset without augmentation
train_ds = datagen.flow_from_directory(
    directory,
    subset="training",
    seed=123,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="categorical"
)

# Load the validation dataset without augmentation
validation_datagen = ImageDataGenerator(validation_split=0.2)

validation_ds = validation_datagen.flow_from_directory(
    directory,
    subset="validation",
    seed=123,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="categorical"
)

# Display some information about the loaded dataset
class_names = list(train_ds.class_indices.keys())
print("Class names:", class_names)

# Define the model
vgg16_model = Sequential()

# Load the pretrained VGG16 model
pretrained_model = tf.keras.applications.VGG16(
    include_top=False,
    input_shape=(img_height, img_width, 3),
    pooling='avg',
    weights='imagenet',
)

# Freeze the layers of the pretrained model
for layer in pretrained_model.layers:
    layer.trainable = False

# Add the pretrained model to the sequential model
vgg16_model.add(pretrained_model)
vgg16_model.add(Flatten())
vgg16_model.add(Dense(512, activation='relu'))
vgg16_model.add(Dense(len(class_names), activation='softmax'))

vgg16_model.summary()
vgg16_model.compile(
    optimizer=Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
epochs = 20
history = vgg16_model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs
)

# Plotting the training history
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylim(0.4, 1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# Generate predictions and plot the confusion matrix
Y_pred = vgg16_model.predict(validation_ds)
y_pred = np.argmax(Y_pred, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(validation_ds.classes, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(20, 20))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 5556 images belonging to 80 classes.
# Python(7320) MallocStackLogging: can't turn off malloc stack logging because it was not enabled.
# Found 1344 images belonging to 80 classes.
# Class names: ['Aloevera', 'Amla', 'Amruthaballi', 'Arali', 'Astma_weed', 'Badipala', 'Balloon_Vine', 'Bamboo', 'Beans', 'Betel', 'Bhrami', 'Bringaraja', 'Caricature', 'Castor', 'Catharanthus', 'Chakte', 'Chilly', 'Citron lime (herelikai)', 'Coffee', 'Common rue(naagdalli)', 'Coriender', 'Curry', 'Doddpathre', 'Drumstick', 'Ekka', 'Eucalyptus', 'Ganigale', 'Ganike', 'Gasagase', 'Ginger', 'Globe Amarnath', 'Guava', 'Henna', 'Hibiscus', 'Honge', 'Insulin', 'Jackfruit', 'Jasmine', 'Kambajala', 'Kasambruga', 'Kohlrabi', 'Lantana', 'Lemon', 'Lemongrass', 'Malabar_Nut', 'Malabar_Spinach', 'Mango', 'Marigold', 'Mint', 'Neem', 'Nelavembu', 'Nerale', 'Nooni', 'Onion', 'Padri', 'Palak(Spinach)', 'Papaya', 'Parijatha', 'Pea', 'Pepper', 'Pomoegranate', 'Pumpkin', 'Raddish', 'Rose', 'Sampige', 'Sapota', 'Seethaashoka', 'Seethapala', 'Spinach1', 'Tamarind', 'Taro', 'Tecoma', 'Thumbe', 'Tomato', 'Tulsi', 'Turmeric', 'ashoka', 'camphor', 'kamakasturi', 'kepala']
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ ?                      │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)
# Epoch 1/20
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2024-07-02 16:21:14.964184: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 16:21:22.933819: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1716s 10s/step - accuracy: 0.2677 - loss: 4.2380 - val_accuracy: 0.3943 - val_loss: 2.9642
# Epoch 2/20
# 2024-07-02 16:49:50.246824: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 16:49:56.444843: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 3938s 23s/step - accuracy: 0.8388 - loss: 0.6106 - val_accuracy: 0.4635 - val_loss: 2.9308
# Epoch 3/20
# 2024-07-02 17:55:29.898300: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 17:55:47.209149: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2778s 16s/step - accuracy: 0.9418 - loss: 0.2291 - val_accuracy: 0.5007 - val_loss: 2.8650
# Epoch 4/20
# 2024-07-02 18:41:48.819339: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 18:42:06.233308: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2430s 14s/step - accuracy: 0.9675 - loss: 0.1337 - val_accuracy: 0.5372 - val_loss: 2.8409
# Epoch 5/20
# 2024-07-02 19:22:18.144414: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 19:22:26.323088: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1661s 9s/step - accuracy: 0.9932 - loss: 0.0459 - val_accuracy: 0.5394 - val_loss: 2.7940
# Epoch 6/20
# 2024-07-02 19:49:56.401113: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 19:50:01.391868: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1672s 10s/step - accuracy: 0.9938 - loss: 0.0455 - val_accuracy: 0.5551 - val_loss: 2.8332
# Epoch 7/20
# 2024-07-02 20:17:50.683757: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 20:17:58.703992: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1740s 10s/step - accuracy: 0.9988 - loss: 0.0149 - val_accuracy: 0.5476 - val_loss: 2.8458
# Epoch 8/20
# 2024-07-02 20:46:49.833201: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 20:46:55.553644: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1967s 11s/step - accuracy: 0.9998 - loss: 0.0084 - val_accuracy: 0.5499 - val_loss: 2.8978
# Epoch 9/20
# 2024-07-02 21:19:37.357009: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 21:19:47.392616: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-02 21:19:51.165525: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2003s 11s/step - accuracy: 1.0000 - loss: 0.0051 - val_accuracy: 0.5432 - val_loss: 2.9436
# Epoch 10/20
# 2024-07-02 21:53:00.254128: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 21:53:05.840861: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1727s 10s/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.5543 - val_loss: 2.9985
# Epoch 11/20
# 2024-07-02 22:22:22.613844: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 22:22:29.836772: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1334s 7s/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.5580 - val_loss: 3.0383
# Epoch 12/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1257s 7s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.5573 - val_loss: 3.0790
# Epoch 13/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1397s 8s/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.5565 - val_loss: 3.0913
# Epoch 14/20
# 2024-07-02 23:28:14.876170: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-02 23:28:15.897631: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1310s 7s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.5610 - val_loss: 3.1246
# Epoch 15/20
# 2024-07-02 23:50:04.701809: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-02 23:50:05.743448: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1258s 7s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 0.5588 - val_loss: 3.1520
# Epoch 16/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1262s 7s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5580 - val_loss: 3.1838
# Epoch 17/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1159s 7s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.5588 - val_loss: 3.1987
# Epoch 18/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 958s 5s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.5595 - val_loss: 3.2221
# Epoch 19/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 965s 6s/step - accuracy: 1.0000 - loss: 9.1651e-04 - val_accuracy: 0.5565 - val_loss: 3.2331
# Epoch 20/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 978s 6s/step - accuracy: 1.0000 - loss: 7.8696e-04 - val_accuracy: 0.5565 - val_loss: 3.2602
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 193s 5s/step

# %%
vgg16_model.save("/Users/shauryasharma/Desktop/Saved Models/VGG16.keras")

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

# Define the layers of the model
layers = [
    "Input Layer\n(224x224x3)",
    "MobileNetV3",
    "Flatten Layer",
    "Dense Layer\n(512 neurons, ReLU)",
    "Output Layer\n(Softmax)"
]

# Create figure and axis
fig, ax = plt.subplots(figsize=(12, 6))

# Custom colors
bg_color = '#F0F0F0'
box_color = '#3498db'
arrow_color = '#2c3e50'
text_color = '#2c3e50'

# Set background color
fig.patch.set_facecolor(bg_color)
ax.set_facecolor(bg_color)

# Plot the layers
for i, layer in enumerate(layers):
    # Create rounded rectangle for each layer
    rect = patches.FancyBboxPatch((i-0.4, 0.3), 0.8, 0.4, 
                                  boxstyle="round,pad=0.03", 
                                  facecolor=box_color, 
                                  edgecolor=arrow_color, 
                                  linewidth=2, 
                                  alpha=0.8)
    ax.add_patch(rect)
    
    # Add layer text
    ax.text(i, 0.5, layer, va='center', ha='center', 
            color=text_color, 
            fontsize=10, 
            fontweight='bold', 
            fontfamily='sans-serif', 
            wrap=True)
    
    # Add arrows between layers (except for the first layer)
    if i > 0:
        ax.annotate("", xy=(i-0.45, 0.5), xytext=(i-0.95, 0.5),
                    arrowprops=dict(arrowstyle="->", color=arrow_color, lw=2))

# Set axis properties
ax.set_xlim(-0.5, len(layers)-0.5)
ax.set_ylim(0, 1)
ax.axis('off')

# Add title with background color
title = ax.set_title('Neural Network Architecture', 
                     fontsize=18, 
                     fontweight='bold', 
                     fontfamily='sans-serif', 
                     pad=60, 
                     color=text_color)
title.set_bbox(dict(facecolor=bg_color, edgecolor='none', alpha=0.8))

# Display the plot
plt.tight_layout()
plt.show()
