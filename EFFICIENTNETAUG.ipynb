# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import ImageFile
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Ensure that truncated images are loaded
ImageFile.LOAD_TRUNCATED_IMAGES = True


# Parameters
img_height = 224  # EfficientNet requires 224x224 images
img_width = 224
batch_size = 32
directory = r"/Users/shauryasharma/Downloads/Indian Medicinal Leaves Image Datasets/Medicinal Leaf dataset"

# Define data augmentation parameters
datagen = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    fill_mode='nearest',
    validation_split=0.2  # Add validation split here
)

# Load the training dataset with augmentation
train_ds = datagen.flow_from_directory(
    directory,
    subset="training",
    seed=123,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="categorical"
)

# Load the validation dataset without augmentation
validation_datagen = ImageDataGenerator(validation_split=0.2)

validation_ds = validation_datagen.flow_from_directory(
    directory,
    subset="validation",
    seed=123,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="categorical"
)

# Display some information about the loaded dataset
class_names = list(train_ds.class_indices.keys())
print("Class names:", class_names)

# Define the model
efficientnet_model = Sequential()

# Load the pretrained EfficientNet model
pretrained_model = tf.keras.applications.EfficientNetB0(
    include_top=False,
    input_shape=(img_height, img_width, 3),
    pooling='avg',
    weights='imagenet',
)

# Freeze the layers of the pretrained model
for layer in pretrained_model.layers:
    layer.trainable = False

# Add the pretrained model to the sequential model
efficientnet_model.add(pretrained_model)
efficientnet_model.add(Flatten())
efficientnet_model.add(Dense(512, activation='relu'))
efficientnet_model.add(Dense(len(class_names), activation='softmax'))

efficientnet_model.summary()
efficientnet_model.compile(
    optimizer=Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
epochs = 20
history = efficientnet_model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs
)

# Plotting the training history
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylim(0.4, 1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# Generate predictions and plot the confusion matrix
Y_pred = efficientnet_model.predict(validation_ds)
y_pred = np.argmax(Y_pred, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(validation_ds.classes, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(20, 20))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 5556 images belonging to 80 classes.
# Found 1344 images belonging to 80 classes.
# Class names: ['Aloevera', 'Amla', 'Amruthaballi', 'Arali', 'Astma_weed', 'Badipala', 'Balloon_Vine', 'Bamboo', 'Beans', 'Betel', 'Bhrami', 'Bringaraja', 'Caricature', 'Castor', 'Catharanthus', 'Chakte', 'Chilly', 'Citron lime (herelikai)', 'Coffee', 'Common rue(naagdalli)', 'Coriender', 'Curry', 'Doddpathre', 'Drumstick', 'Ekka', 'Eucalyptus', 'Ganigale', 'Ganike', 'Gasagase', 'Ginger', 'Globe Amarnath', 'Guava', 'Henna', 'Hibiscus', 'Honge', 'Insulin', 'Jackfruit', 'Jasmine', 'Kambajala', 'Kasambruga', 'Kohlrabi', 'Lantana', 'Lemon', 'Lemongrass', 'Malabar_Nut', 'Malabar_Spinach', 'Mango', 'Marigold', 'Mint', 'Neem', 'Nelavembu', 'Nerale', 'Nooni', 'Onion', 'Padri', 'Palak(Spinach)', 'Papaya', 'Parijatha', 'Pea', 'Pepper', 'Pomoegranate', 'Pumpkin', 'Raddish', 'Rose', 'Sampige', 'Sapota', 'Seethaashoka', 'Seethapala', 'Spinach1', 'Tamarind', 'Taro', 'Tecoma', 'Thumbe', 'Tomato', 'Tulsi', 'Turmeric', 'ashoka', 'camphor', 'kamakasturi', 'kepala']
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)     │ ?                      │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,049,571 (15.45 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 4,049,571 (15.45 MB)
# Epoch 1/20
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2024-07-02 19:54:45.989093: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 19:54:59.217802: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 19:55:09.985501: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1010s 6s/step - accuracy: 0.3095 - loss: 3.0200 - val_accuracy: 0.4829 - val_loss: 1.9354
# Epoch 2/20
# 2024-07-02 20:11:20.199491: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 20:11:32.120263: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 20:11:40.769282: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 976s 5s/step - accuracy: 0.7840 - loss: 0.8435 - val_accuracy: 0.5685 - val_loss: 1.7024
# Epoch 3/20
# 2024-07-02 20:27:37.131204: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 20:27:56.928175: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 990s 6s/step - accuracy: 0.8737 - loss: 0.4724 - val_accuracy: 0.6168 - val_loss: 1.5846
# Epoch 4/20
# 2024-07-02 20:44:05.407816: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 20:44:17.518780: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 20:44:28.045478: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1003s 6s/step - accuracy: 0.9036 - loss: 0.3528 - val_accuracy: 0.6057 - val_loss: 1.6154
# Epoch 5/20
# 2024-07-02 21:00:52.754822: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 21:01:11.266505: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-02 21:01:16.499746: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1218s 7s/step - accuracy: 0.9208 - loss: 0.2837 - val_accuracy: 0.6295 - val_loss: 1.6562
# Epoch 6/20
# 2024-07-02 21:21:09.556310: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 21:21:27.809794: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 21:21:42.745038: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1255s 7s/step - accuracy: 0.9313 - loss: 0.2323 - val_accuracy: 0.6391 - val_loss: 1.6160
# Epoch 7/20
# 2024-07-02 21:42:02.756108: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 21:42:20.360823: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-02 21:42:24.587250: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 971s 5s/step - accuracy: 0.9529 - loss: 0.1720 - val_accuracy: 0.6324 - val_loss: 1.6553
# Epoch 8/20
# 2024-07-02 21:58:17.704727: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 21:58:36.327835: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-02 21:58:40.673680: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 988s 5s/step - accuracy: 0.9599 - loss: 0.1487 - val_accuracy: 0.6622 - val_loss: 1.6056
# Epoch 9/20
# 2024-07-02 22:14:39.854614: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 2 of 8
# 2024-07-02 22:14:51.231318: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 22:15:00.531380: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 903s 5s/step - accuracy: 0.9572 - loss: 0.1407 - val_accuracy: 0.6577 - val_loss: 1.5456
# Epoch 10/20
# 2024-07-02 22:29:44.807539: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 22:29:50.816124: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 670s 4s/step - accuracy: 0.9709 - loss: 0.1136 - val_accuracy: 0.6510 - val_loss: 1.6791
# Epoch 11/20
# 2024-07-02 22:40:52.927485: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 22:41:05.371434: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 687s 4s/step - accuracy: 0.9726 - loss: 0.1063 - val_accuracy: 0.6540 - val_loss: 1.6889
# Epoch 12/20
# 2024-07-02 22:52:19.325640: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 22:52:32.198620: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 727s 4s/step - accuracy: 0.9695 - loss: 0.1080 - val_accuracy: 0.6332 - val_loss: 1.7380
# Epoch 13/20
# 2024-07-02 23:04:26.138069: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 23:04:36.911268: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 23:04:45.596461: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 798s 4s/step - accuracy: 0.9664 - loss: 0.1048 - val_accuracy: 0.6399 - val_loss: 1.8123
# Epoch 14/20
# 2024-07-02 23:17:45.528969: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 23:17:59.701522: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 813s 5s/step - accuracy: 0.9709 - loss: 0.1020 - val_accuracy: 0.6622 - val_loss: 1.7549
# Epoch 15/20
# 2024-07-02 23:31:17.372834: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 23:31:28.123511: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 23:31:34.127906: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 767s 4s/step - accuracy: 0.9724 - loss: 0.1038 - val_accuracy: 0.6265 - val_loss: 1.9500
# Epoch 16/20
# 2024-07-02 23:44:05.150556: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 23:44:15.697988: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 23:44:21.694765: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 711s 4s/step - accuracy: 0.9725 - loss: 0.0936 - val_accuracy: 0.6674 - val_loss: 1.8218
# Epoch 17/20
# 2024-07-02 23:55:57.104694: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 23:56:10.183516: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 729s 4s/step - accuracy: 0.9681 - loss: 0.1009 - val_accuracy: 0.6592 - val_loss: 1.7780
# Epoch 18/20
# 2024-07-03 00:08:06.352102: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-03 00:08:18.967295: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 721s 4s/step - accuracy: 0.9661 - loss: 0.0995 - val_accuracy: 0.6503 - val_loss: 1.8759
# Epoch 19/20
# 2024-07-03 00:20:08.013051: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-03 00:20:21.984159: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 721s 4s/step - accuracy: 0.9794 - loss: 0.0670 - val_accuracy: 0.6570 - val_loss: 1.9893
# Epoch 20/20
# 2024-07-03 00:32:08.491307: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:2: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-03 00:32:11.669420: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 709s 4s/step - accuracy: 0.9781 - loss: 0.0713 - val_accuracy: 0.6622 - val_loss: 1.9691
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 131s 3s/step

# %%
efficientnet_model.save("/Users/shauryasharma/Desktop/Saved Models/EFFICIENTNETAUG.keras")
