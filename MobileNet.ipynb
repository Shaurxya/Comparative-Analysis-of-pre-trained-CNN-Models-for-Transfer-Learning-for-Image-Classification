# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import ImageFile
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Ensure that truncated images are loaded
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Parameters
img_height = 224  # MobileNetV3 requires 224x224 images
img_width = 224
batch_size = 32
directory = r"/Users/shauryasharma/Downloads/Indian Medicinal Leaves Image Datasets/Medicinal Leaf dataset"

# Define data generator without augmentation
datagen = ImageDataGenerator(
    validation_split=0.2  # Add validation split here
)

# Load the training dataset without augmentation
train_ds = datagen.flow_from_directory(
    directory,
    subset="training",
    seed=123,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="categorical"
)

# Load the validation dataset without augmentation
validation_datagen = ImageDataGenerator(validation_split=0.2)

validation_ds = validation_datagen.flow_from_directory(
    directory,
    subset="validation",
    seed=123,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="categorical"
)

# Display some information about the loaded dataset
class_names = list(train_ds.class_indices.keys())
print("Class names:", class_names)

# Define the model
mobilenet_model = Sequential()

# Load the pretrained MobileNetV3 model
pretrained_model = tf.keras.applications.MobileNetV3Large(
    include_top=False,
    input_shape=(img_height, img_width, 3),
    pooling='avg',
    weights='imagenet',
)

# Freeze the layers of the pretrained model
for layer in pretrained_model.layers:
    layer.trainable = False

# Add the pretrained model to the sequential model
mobilenet_model.add(pretrained_model)
mobilenet_model.add(Flatten())
mobilenet_model.add(Dense(512, activation='relu'))
mobilenet_model.add(Dense(len(class_names), activation='softmax'))

mobilenet_model.summary()
mobilenet_model.compile(
    optimizer=Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
epochs = 20
history = mobilenet_model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs
)

# Plotting the training history
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylim(0.4, 1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# Generate predictions and plot the confusion matrix
Y_pred = mobilenet_model.predict(validation_ds)
y_pred = np.argmax(Y_pred, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(validation_ds.classes, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(20, 20))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 5556 images belonging to 80 classes.
# Found 1344 images belonging to 80 classes.
# Class names: ['Aloevera', 'Amla', 'Amruthaballi', 'Arali', 'Astma_weed', 'Badipala', 'Balloon_Vine', 'Bamboo', 'Beans', 'Betel', 'Bhrami', 'Bringaraja', 'Caricature', 'Castor', 'Catharanthus', 'Chakte', 'Chilly', 'Citron lime (herelikai)', 'Coffee', 'Common rue(naagdalli)', 'Coriender', 'Curry', 'Doddpathre', 'Drumstick', 'Ekka', 'Eucalyptus', 'Ganigale', 'Ganike', 'Gasagase', 'Ginger', 'Globe Amarnath', 'Guava', 'Henna', 'Hibiscus', 'Honge', 'Insulin', 'Jackfruit', 'Jasmine', 'Kambajala', 'Kasambruga', 'Kohlrabi', 'Lantana', 'Lemon', 'Lemongrass', 'Malabar_Nut', 'Malabar_Spinach', 'Mango', 'Marigold', 'Mint', 'Neem', 'Nelavembu', 'Nerale', 'Nooni', 'Onion', 'Padri', 'Palak(Spinach)', 'Papaya', 'Parijatha', 'Pea', 'Pepper', 'Pomoegranate', 'Pumpkin', 'Raddish', 'Rose', 'Sampige', 'Sapota', 'Seethaashoka', 'Seethapala', 'Spinach1', 'Tamarind', 'Taro', 'Tecoma', 'Thumbe', 'Tomato', 'Tulsi', 'Turmeric', 'ashoka', 'camphor', 'kamakasturi', 'kepala']
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ MobilenetV3large (Functional)   │ ?                      │     2,996,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,996,352 (11.43 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 2,996,352 (11.43 MB)
# Epoch 1/20
# 2024-07-02 13:54:40.906571: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 13:54:45.584446: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 480s 3s/step - accuracy: 0.3878 - loss: 2.7251 - val_accuracy: 0.5365 - val_loss: 1.8814
# Epoch 2/20
# 2024-07-02 14:02:37.610597: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 14:02:40.045764: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 463s 3s/step - accuracy: 0.9115 - loss: 0.3623 - val_accuracy: 0.5595 - val_loss: 1.8670
# Epoch 3/20
# 2024-07-02 14:10:20.344124: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 14:10:24.602545: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 501s 3s/step - accuracy: 0.9730 - loss: 0.1398 - val_accuracy: 0.6124 - val_loss: 1.6196
# Epoch 4/20
# 2024-07-02 14:18:41.999383: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 14:18:46.514789: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 511s 3s/step - accuracy: 0.9875 - loss: 0.0722 - val_accuracy: 0.6369 - val_loss: 1.6326
# Epoch 5/20
# 2024-07-02 14:27:12.045006: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 14:27:17.408053: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 520s 3s/step - accuracy: 0.9978 - loss: 0.0283 - val_accuracy: 0.6585 - val_loss: 1.6175
# Epoch 6/20
# 2024-07-02 14:35:52.564321: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 14:35:59.132069: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 525s 3s/step - accuracy: 0.9986 - loss: 0.0169 - val_accuracy: 0.6562 - val_loss: 1.6882
# Epoch 7/20
# 2024-07-02 14:44:37.996584: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 14:44:43.104761: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 442s 2s/step - accuracy: 0.9993 - loss: 0.0107 - val_accuracy: 0.6577 - val_loss: 1.6771
# Epoch 8/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 243s 1s/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.6622 - val_loss: 1.6569
# Epoch 9/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 1.0000 - loss: 0.0044 - val_accuracy: 0.6629 - val_loss: 1.6849
# Epoch 10/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.6696 - val_loss: 1.6975
# Epoch 11/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 428s 2s/step - accuracy: 1.0000 - loss: 0.0029 - val_accuracy: 0.6689 - val_loss: 1.6987
# Epoch 12/20
# 2024-07-02 15:11:15.901423: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 15:11:32.367926: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 764s 4s/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.6778 - val_loss: 1.7114
# Epoch 13/20
# 2024-07-02 15:24:00.132162: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 15:24:11.109262: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-02 15:24:13.792695: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 794s 4s/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.6741 - val_loss: 1.7352
# Epoch 14/20
# 2024-07-02 15:37:15.196222: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:14: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 15:37:26.638352: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 405s 2s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 0.6682 - val_loss: 1.7502
# Epoch 15/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6674 - val_loss: 1.7694
# Epoch 16/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 238s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6741 - val_loss: 1.7684
# Epoch 17/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6749 - val_loss: 1.7803
# Epoch 18/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 239s 1s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.6734 - val_loss: 1.8030
# Epoch 19/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 237s 1s/step - accuracy: 1.0000 - loss: 8.8005e-04 - val_accuracy: 0.6778 - val_loss: 1.8170
# Epoch 20/20
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 783s 4s/step - accuracy: 1.0000 - loss: 7.7338e-04 - val_accuracy: 0.6778 - val_loss: 1.8273
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 121s 3s/step

# %%
mobilenet_model.save("/Users/shauryasharma/Desktop/Saved Models/MobileNet.keras")
