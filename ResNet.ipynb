# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from PIL import ImageFile
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Ensure that truncated images are loaded
ImageFile.LOAD_TRUNCATED_IMAGES = True

# Parameters
img_height = 224  # ResNet-50 requires 224x224 images
img_width = 224
batch_size = 32
directory = r"/Users/shauryasharma/Downloads/Indian Medicinal Leaves Image Datasets/Medicinal Leaf dataset"

# Define data generator without augmentation
datagen = ImageDataGenerator(
    validation_split=0.2  # Add validation split here
)

# Load the training dataset without augmentation
train_ds = datagen.flow_from_directory(
    directory,
    subset="training",
    seed=123,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="categorical"
)

# Load the validation dataset without augmentation
validation_datagen = ImageDataGenerator(validation_split=0.2)

validation_ds = validation_datagen.flow_from_directory(
    directory,
    subset="validation",
    seed=123,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode="categorical"
)

# Display some information about the loaded dataset
class_names = list(train_ds.class_indices.keys())
print("Class names:", class_names)

# Define the model
resnet_model = Sequential()

# Load the pretrained ResNet-50 model
pretrained_model = tf.keras.applications.ResNet50(
    include_top=False,
    input_shape=(img_height, img_width, 3),
    pooling='avg',
    weights='imagenet',
)

# Freeze the layers of the pretrained model
for layer in pretrained_model.layers:
    layer.trainable = False

# Add the pretrained model to the sequential model
resnet_model.add(pretrained_model)
resnet_model.add(Flatten())
resnet_model.add(Dense(512, activation='relu'))
resnet_model.add(Dense(len(class_names), activation='softmax'))

resnet_model.summary()
resnet_model.compile(
    optimizer=Adam(),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# Train the model
epochs = 20
history = resnet_model.fit(
    train_ds,
    validation_data=validation_ds,
    epochs=epochs
)

# Plotting the training history
fig1 = plt.gcf()
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.ylim(0.4, 1)
plt.grid()
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'validation'])
plt.show()

# Generate predictions and plot the confusion matrix
Y_pred = resnet_model.predict(validation_ds)
y_pred = np.argmax(Y_pred, axis=1)

# Compute the confusion matrix
cm = confusion_matrix(validation_ds.classes, y_pred)

# Plot the confusion matrix
plt.figure(figsize=(20, 20))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()
# Out:
# Found 5556 images belonging to 80 classes.
# Found 1344 images belonging to 80 classes.
# Class names: ['Aloevera', 'Amla', 'Amruthaballi', 'Arali', 'Astma_weed', 'Badipala', 'Balloon_Vine', 'Bamboo', 'Beans', 'Betel', 'Bhrami', 'Bringaraja', 'Caricature', 'Castor', 'Catharanthus', 'Chakte', 'Chilly', 'Citron lime (herelikai)', 'Coffee', 'Common rue(naagdalli)', 'Coriender', 'Curry', 'Doddpathre', 'Drumstick', 'Ekka', 'Eucalyptus', 'Ganigale', 'Ganike', 'Gasagase', 'Ginger', 'Globe Amarnath', 'Guava', 'Henna', 'Hibiscus', 'Honge', 'Insulin', 'Jackfruit', 'Jasmine', 'Kambajala', 'Kasambruga', 'Kohlrabi', 'Lantana', 'Lemon', 'Lemongrass', 'Malabar_Nut', 'Malabar_Spinach', 'Mango', 'Marigold', 'Mint', 'Neem', 'Nelavembu', 'Nerale', 'Nooni', 'Onion', 'Padri', 'Palak(Spinach)', 'Papaya', 'Parijatha', 'Pea', 'Pepper', 'Pomoegranate', 'Pumpkin', 'Raddish', 'Rose', 'Sampige', 'Sapota', 'Seethaashoka', 'Seethapala', 'Spinach1', 'Tamarind', 'Taro', 'Tecoma', 'Thumbe', 'Tomato', 'Tulsi', 'Turmeric', 'ashoka', 'camphor', 'kamakasturi', 'kepala']
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ ?                      │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 23,587,712 (89.98 MB)
# Epoch 1/20
# 2024-07-02 16:09:24.815407: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 2 of 8
# 2024-07-02 16:09:36.548400: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 16:09:53.449593: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 857s 5s/step - accuracy: 0.3661 - loss: 2.8607 - val_accuracy: 0.4829 - val_loss: 2.2836
# Epoch 2/20
# 2024-07-02 16:23:23.988743: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 16:23:35.446330: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 912s 5s/step - accuracy: 0.8626 - loss: 0.5010 - val_accuracy: 0.5618 - val_loss: 2.0852
# Epoch 3/20
# 2024-07-02 16:38:39.065239: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 16:38:52.015395: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 880s 5s/step - accuracy: 0.9436 - loss: 0.2158 - val_accuracy: 0.5729 - val_loss: 2.0200
# Epoch 4/20
# 2024-07-02 16:53:19.414378: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 16:53:29.049952: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 2860s 16s/step - accuracy: 0.9675 - loss: 0.1267 - val_accuracy: 0.5997 - val_loss: 2.0880
# Epoch 5/20
# 2024-07-02 17:40:58.191805: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 17:41:07.994098: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1522s 9s/step - accuracy: 0.9895 - loss: 0.0579 - val_accuracy: 0.5997 - val_loss: 2.1273
# Epoch 6/20
# 2024-07-02 18:06:22.216777: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 18:06:33.477287: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 18:06:49.996109: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1425s 8s/step - accuracy: 0.9923 - loss: 0.0505 - val_accuracy: 0.6302 - val_loss: 2.0067
# Epoch 7/20
# 2024-07-02 18:30:04.443771: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 18:30:27.800373: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-02 18:30:32.527888: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1511s 8s/step - accuracy: 0.9988 - loss: 0.0133 - val_accuracy: 0.6243 - val_loss: 2.0623
# Epoch 8/20
# 2024-07-02 18:55:13.695588: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 18:55:24.970102: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 18:55:32.166708: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1260s 7s/step - accuracy: 1.0000 - loss: 0.0064 - val_accuracy: 0.6295 - val_loss: 2.0845
# Epoch 9/20
# 2024-07-02 19:16:14.624745: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 19:16:25.784734: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 6 of 8
# 2024-07-02 19:16:32.482264: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1123s 6s/step - accuracy: 1.0000 - loss: 0.0046 - val_accuracy: 0.6406 - val_loss: 2.0891
# Epoch 10/20
# 2024-07-02 19:34:56.017978: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 19:35:03.563202: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 754s 4s/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.6369 - val_loss: 2.1433
# Epoch 11/20
# 2024-07-02 19:47:31.253197: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 5 of 8
# 2024-07-02 19:47:38.725300: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 788s 4s/step - accuracy: 1.0000 - loss: 0.0030 - val_accuracy: 0.6280 - val_loss: 2.1821
# Epoch 12/20
# 2024-07-02 20:00:39.190024: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 20:00:53.176073: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 926s 5s/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.6369 - val_loss: 2.1715
# Epoch 13/20
# 2024-07-02 20:16:05.609082: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 20:16:18.646126: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 907s 5s/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.6369 - val_loss: 2.2131
# Epoch 14/20
# 2024-07-02 20:31:10.673758: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 20:31:21.971242: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 915s 5s/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 0.6302 - val_loss: 2.2062
# Epoch 15/20
# 2024-07-02 20:46:25.001343: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 20:46:37.357333: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 937s 5s/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.6310 - val_loss: 2.2558
# Epoch 16/20
# 2024-07-02 21:02:03.860676: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 21:02:20.932670: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1135s 6s/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.6317 - val_loss: 2.2567
# Epoch 17/20
# 2024-07-02 21:21:01.289110: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 21:21:15.999540: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-02 21:21:20.859163: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 1175s 7s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 0.6295 - val_loss: 2.2737
# Epoch 18/20
# 2024-07-02 21:40:31.825422: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 3 of 8
# 2024-07-02 21:40:45.755656: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 7 of 8
# 2024-07-02 21:40:48.386082: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 910s 5s/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 0.6302 - val_loss: 2.2993
# Epoch 19/20
# 2024-07-02 21:55:44.287068: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 21:55:56.396697: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 909s 5s/step - accuracy: 1.0000 - loss: 0.0010 - val_accuracy: 0.6339 - val_loss: 2.3288
# Epoch 20/20
# 2024-07-02 22:10:52.300903: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:450] ShuffleDatasetV3:8: Filling up shuffle buffer (this may take a while): 4 of 8
# 2024-07-02 22:11:03.621832: I tensorflow/core/kernels/data/shuffle_dataset_op.cc:480] Shuffle buffer filled.
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 867s 5s/step - accuracy: 1.0000 - loss: 9.5805e-04 - val_accuracy: 0.6302 - val_loss: 2.3415
# 42/42 ━━━━━━━━━━━━━━━━━━━━ 181s 4s/step

# %%
resnet_model.save("/Users/shauryasharma/Desktop/Saved Models/ResNet.keras")
